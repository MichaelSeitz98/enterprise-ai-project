# %%
import pandas as pd

# %%
data = pd.read_csv(r'C:\Users\mbauer2\workspace\Uni\enterprise-ai-project\ImmmoWelt_Price_Guide\flats_to_buy_preproceesed.csv')

# %%
data
# Out:
#                                           Url  \
# 0    "https://www.immowelt.de/expose/2ar9w55"
# 1    "https://www.immowelt.de/expose/2aaaw55"
# 2    "https://www.immowelt.de/expose/2agdg5f"
# 3    "https://www.immowelt.de/expose/2ak8w55"
# 4    "https://www.immowelt.de/expose/27zeu5l"
# ..                                        ...
# 282  "https://www.immowelt.de/expose/2a42q5g"
# 283  "https://www.immowelt.de/expose/2as2559"
# 284  "https://www.immowelt.de/expose/28bd354"
# 285  "https://www.immowelt.de/expose/2a76559"
# 286  "https://www.immowelt.de/expose/2aqsx56"
#
#                                                  Title Object_price  \
# 0                                "Ried 67.5 - OPTIMAL"       536000
# 1                                "Ried 67.6 - PASSEND"       556000
# 2    "++2- Zi. ETW mit ca. 53m\u00b2 in W\u00fcrzbu...       220000
# 3                                  "Ried 67.1 - IDEAL"       645000
# ...

# %%
data.drop(columns=['Price', 'MediaItems', 'ContactData'], inplace=True)

# %%
data.drop(columns='BasicInfo', inplace=True)

# %%
data
# Out:
#                                           Url  \
# 0    "https://www.immowelt.de/expose/2ar9w55"
# 1    "https://www.immowelt.de/expose/2aaaw55"
# 2    "https://www.immowelt.de/expose/2agdg5f"
# 3    "https://www.immowelt.de/expose/2ak8w55"
# 4    "https://www.immowelt.de/expose/27zeu5l"
# ..                                        ...
# 282  "https://www.immowelt.de/expose/2a42q5g"
# 283  "https://www.immowelt.de/expose/2as2559"
# 284  "https://www.immowelt.de/expose/28bd354"
# 285  "https://www.immowelt.de/expose/2a76559"
# 286  "https://www.immowelt.de/expose/2aqsx56"
#
#                                                  Title Object_price  \
# 0                                "Ried 67.5 - OPTIMAL"       536000
# 1                                "Ried 67.6 - PASSEND"       556000
# 2    "++2- Zi. ETW mit ca. 53m\u00b2 in W\u00fcrzbu...       220000
# 3                                  "Ried 67.1 - IDEAL"       645000
# ...

# %%
data.columns
# Out:
# Index(['Url', 'Title', 'Object_price', 'Object_currency', 'LivingSpace',
#        'Rooms', 'ConstructionYear', 'Price', 'MediaItems', 'ContactData',
#        'BasicInfo', 'ZipCode', 'EstateTypeGerman', 'DistributionTypeGerman',
#        'EstateType', 'DistributionType', 'abstellraum',
#        'als_ferienimmobilie_geeignet', 'altbau_(bis_1945)', 'bad/wc_getrennt',
#        'balkon', 'barriefrei', 'block', 'carport', 'dachgeschoss',
#        'denkmalgeschuetzt', 'dielen', 'dsl', 'duplex', 'dusche',
#        'einbauk\u00fcche', 'elektro', 'erdgeschoss', 'erstbezug', 'estrich',
#        'etagenheizung', 'fenster', 'fern', 'ferne', 'fliesen', 'fluessiggas',
#        'frei', 'fu\u00dfbodenheizung', 'gaestewc', 'garage', 'garten',
#        'gartennutzung', 'gas', 'gepflegt', 'haustiere_erlaubt', 'holzfenster',
#        'kable_sat_tv', 'kamera', 'kamin', 'kapitalanlage', 'kelleranteil',
#        'kfw40', 'kfw55', 'kfw70',
# ...

# %%
data.to_csv(r'C:\Users\mbauer2\workspace\Uni\enterprise-ai-project\ImmmoWelt_Price_Guide\flats_to_buy_preproceesed_forAtoTrain.csv', index=False)
