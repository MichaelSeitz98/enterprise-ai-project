# %%
# Out:
# ---------------------------------------------------------------------------
# ApifyApiError                             Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21208\2629338297.py in <cell line: 16>()
#      14
#      15 # Run the Actor and wait for it to finish
# ---> 16 run = client.actor("WKTZJMCzDQvBzR29a").call(run_input=run_input)
#      17
#      18 # Fetch and print Actor results from the run's dataset (if there are any)
#
# c:\Users\FelixNeubauer\anaconda3\envs\py38\lib\site-packages\apify_client\_logging.py in wrapper(resource_client, *args, **kwargs)
#      66             ctx_url.set(resource_client.url)
#      67
# ---> 68             return fun(resource_client, *args, **kwargs)
#      69         return wrapper
#      70
#
# c:\Users\FelixNeubauer\anaconda3\envs\py38\lib\site-packages\apify_client\clients\resource_clients\actor.py in call(self, run_input, content_type, build, memory_mbytes, timeout_secs, webhooks, wait_secs)
# ...
